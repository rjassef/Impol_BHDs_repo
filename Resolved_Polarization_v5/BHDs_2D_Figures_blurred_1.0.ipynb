# %%
import numpy as np
from resolved_pol import ResolvedPol

# %%
#no_processing = True
no_processing = False
stamps_folder="stamps_blurred_1.0"
blurr_PSF_FWHM=1.0

# %%
snr_stack_lim = 7.0

# %% [markdown]
# ## W0019-1046

# %%
bhd = ResolvedPol("W0019-1046", "R_SPECIAL", star_coords=(1470.5, 84), stamps_folder=stamps_folder) #star_coords=(1145,37.5))
bhd.get_pol(no_processing=no_processing, blurr_PSF_FWHM=blurr_PSF_FWHM)

seeing_values = list(bhd.seeing.values())
print(np.min(seeing_values), np.max(seeing_values))
# Out:
# mkdir: work: File exists
# #######
# 3565057.60201
# #######
#
# Matching to image science_reduced_img.W0019-1046.60201.R_SPECIAL.chip1.8.fits.
#
# #######
# 3565577.60202
# #######
#
# Matching to image science_reduced_img.W0019-1046.60202.R_SPECIAL.chip1.1.fits.
#
# #######
# All
# #######
#
# Matching to image science_reduced_img.W0019-1046.60201.R_SPECIAL.chip1.8.fits.
# 0.4835 1.5288

# %%
bhd.plot_pol(3., 10.0, 0., 180., z=1.641, save_fig=True, snr_stack_lim=snr_stack_lim, blurr_PSF_FWHM=blurr_PSF_FWHM)
# Out:
# /Volumes/PortableSSD/Impol_BHDs_repo/Resolved_Polarization_v5/resolved_pol.py:411: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# ## W0204-0506

# %%
bhd = ResolvedPol("W0204-0506", "R_SPECIAL", star_coords=(1086.5, 222.5),stamps_folder=stamps_folder)#, star_coords=(1012.7, 54.8))
bhd.get_pol(no_processing=no_processing)

seeing_values = list(bhd.seeing.values())
print(np.min(seeing_values), np.max(seeing_values))
print(bhd.target_seeing)
# Out:
# mkdir: stamps_blurred_1.0: File exists
# mkdir: work: File exists
# #######
# 3565504.60209
# #######
#
# Matching to image science_reduced_img.W0204-0506.60209.R_SPECIAL.chip1.3.fits.
#
# #######
# 3565580.60207
# #######
#
# Matching to image science_reduced_img.W0204-0506.60207.R_SPECIAL.chip1.7.fits.
#
# #######
# All
# #######
#
# Matching to image science_reduced_img.W0204-0506.60209.R_SPECIAL.chip1.3.fits.
# 0.4835 1.5288
# {'3565504.60209': 0.8596, '3565580.60207': 0.6794, 'All': 0.8596}

# %%
bhd.plot_pol(20.0, 35., 0., 180., z=2.1, save_fig=True, snr_stack_lim=snr_stack_lim, blurr_PSF_FWHM=blurr_PSF_FWHM)
# Out:
# /Volumes/PortableSSD/Impol_BHDs_repo/Resolved_Polarization_v5/resolved_pol.py:411: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# ## W0220+0137

# %%
bhd = ResolvedPol("W0220+0137", "R_SPECIAL", star_coords=(1600, 262),stamps_folder=stamps_folder)
bhd.get_pol(no_processing=no_processing)

seeing_values = list(bhd.seeing.values())
print(np.min(seeing_values), np.max(seeing_values))
print(bhd.target_seeing)
# Out:
# mkdir: stamps_blurred_1.0: File exists
# mkdir: work: File exists
# #######
# 3565583.60201
# #######
#
# Matching to image science_reduced_img.W0220+0137.60201.R_SPECIAL.chip1.4.fits.
#
# #######
# 3565623.60207
# #######
#
# Matching to image science_reduced_img.W0220+0137.60207.R_SPECIAL.chip1.8.fits.
#
# #######
# All
# #######
#
# Matching to image science_reduced_img.W0220+0137.60201.R_SPECIAL.chip1.4.fits.
# 0.4835 1.5288
# {'3565583.60201': 1.106, '3565623.60207': 0.6754, 'All': 1.106}

# %%
bhd.plot_pol(10., 20., 0., 180., z=3.122, save_fig=True, snr_stack_lim=snr_stack_lim, blurr_PSF_FWHM=blurr_PSF_FWHM)
# Out:
# /Volumes/PortableSSD/Impol_BHDs_repo/Resolved_Polarization_v5/resolved_pol.py:411: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# ## W0831+0140

# %%
bhd = ResolvedPol("W0831+0140", "R_SPECIAL", star_coords=(1010, 404),stamps_folder=stamps_folder)
bhd.get_pol(no_processing=no_processing)

seeing_values = list(bhd.seeing.values())
print(np.min(seeing_values), np.max(seeing_values))
# Out:
# mkdir: stamps_blurred_1.0: File exists
# mkdir: work: File exists
# #######
# 3565626.60290
# #######
#
# Matching to image science_reduced_img.W0831+0140.60290.R_SPECIAL.chip1.8.fits.
#
# #######
# 3565639.60291
# #######
#
# Matching to image science_reduced_img.W0831+0140.60291.R_SPECIAL.chip1.8.fits.
#
# #######
# All
# #######
#
# Matching to image science_reduced_img.W0831+0140.60290.R_SPECIAL.chip1.8.fits.
# 0.4835 1.5288

# %%
bhd.plot_pol(5., 15.0, 0., 180., z=3.912, save_fig=True, snr_stack_lim=snr_stack_lim, blurr_PSF_FWHM=blurr_PSF_FWHM)
# Out:
# /Volumes/PortableSSD/Impol_BHDs_repo/Resolved_Polarization_v5/resolved_pol.py:411: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# ## W0116-0505

# %% [markdown]
# #### $R_{\rm SPECIAL}$

# %%
bhd = ResolvedPol("W0116-0505", "R_SPECIAL", star_coords=(1398, 413),stamps_folder=stamps_folder)
bhd.get_pol(no_processing=no_processing)

seeing_values = list(bhd.seeing.values())
print(np.min(seeing_values), np.max(seeing_values))
# Out:
# mkdir: stamps_blurred_1.0: File exists
# mkdir: work: File exists
# #######
# 2886622.59137
# #######
#
# Matching to image science_reduced_img.W0116-0505.59137.R_SPECIAL.chip1.8.fits.
#
# #######
# 2886765.59136
# #######
#
# Matching to image science_reduced_img.W0116-0505.59136.R_SPECIAL.chip1.1.fits.
#
# #######
# 2886768.59135
# #######
#
# Matching to image science_reduced_img.W0116-0505.59135.R_SPECIAL.chip1.3.fits.
#
# #######
# 2886772.59136
# #######
#
# Matching to image science_reduced_img.W0116-0505.59136.R_SPECIAL.chip1.16.fits.
#
# #######
# All
# #######
#
# Matching to image science_reduced_img.W0116-0505.59136.R_SPECIAL.chip1.16.fits.
# 0.4835 1.5288

# %%
bhd.plot_pol(8., 18., 0., 180., z=3.173, figsize=(37,22), save_fig=True, snr_stack_lim=snr_stack_lim, blurr_PSF_FWHM=blurr_PSF_FWHM)
# Out:
# /Volumes/PortableSSD/Impol_BHDs_repo/Resolved_Polarization_v5/resolved_pol.py:411: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# #### $I_{\rm BESS}$

# %%
bhd = ResolvedPol("W0116-0505", "I_BESS", star_coords=(1398, 413),stamps_folder=stamps_folder)
bhd.get_pol(no_processing=no_processing)

seeing_values = list(bhd.seeing.values())
print(np.min(seeing_values), np.max(seeing_values))
# Out:
# mkdir: stamps_blurred_1.0: File exists
# mkdir: work: File exists
# #######
# 3564862.60146
# #######
#
# Matching to image science_reduced_img.W0116-0505.60146.I_BESS.chip1.8.fits.
#
# #######
# 3564862.60148
# #######
#
# Matching to image science_reduced_img.W0116-0505.60148.I_BESS.chip1.14.fits.
#
# #######
# 3564862.60201
# #######
#
# Matching to image science_reduced_img.W0116-0505.60201.I_BESS.chip1.2.fits.
#
# #######
# 3565005.60148
# #######
#
# Matching to image science_reduced_img.W0116-0505.60148.I_BESS.chip1.4.fits.
#
# #######
# All
# #######
#
# Matching to image science_reduced_img.W0116-0505.60201.I_BESS.chip1.2.fits.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 2
#       1 bhd = ResolvedPol("W0116-0505", "I_BESS", star_coords=(1398, 413),stamps_folder=stamps_folder)
# ----> 2 bhd.get_pol(no_processing=no_processing)
# ...

# %%
bhd.plot_pol(10., 20., 0., 180., z=3.173, figsize=(37,22), save_fig=True, blurr_PSF_FWHM=blurr_PSF_FWHM)

# %% [markdown]
# #### $v_{\rm High}$

# %%
bhd = ResolvedPol("W0116-0505", "v_HIGH", star_coords=(1398, 413),stamps_folder=stamps_folder)
bhd.get_pol(no_processing=no_processing)

seeing_values = list(bhd.seeing.values())
print(np.min(seeing_values), np.max(seeing_values))

# %%
bhd.plot_pol(5., 15., 0., 180., z=3.173, figsize=(10,22), save_fig=True, side_colorbar=True, blurr_PSF_FWHM=blurr_PSF_FWHM)
