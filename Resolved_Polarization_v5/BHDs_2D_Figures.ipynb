# %%
import numpy as np
from resolved_pol import ResolvedPol

# %%
no_processing = True
#no_processing = False

# %%
snr_stack_lim = 5.0

# %% [markdown]
# ## W0019-1046

# %%
bhd = ResolvedPol("W0019-1046", "R_SPECIAL")
bhd.get_pol(no_processing=no_processing)

seeing_values = list(bhd.seeing.values())
print(np.min(seeing_values), np.max(seeing_values))
# Out:
# 0.4835 1.5288
# mkdir: stamps: File exists
# mkdir: work: File exists

# %%
bhd.plot_pol(3., 18.0, 0., 180., z=1.641, save_fig=True, snr_stack_lim=snr_stack_lim)
# Out:
# /Volumes/PortableSSD/Impol_BHDs_repo/Resolved_Polarization_v5/resolved_pol.py:411: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# ## W0204-0506

# %%
bhd = ResolvedPol("W0204-0506", "R_SPECIAL")
bhd.get_pol(no_processing=no_processing)

seeing_values = list(bhd.seeing.values())
print(np.min(seeing_values), np.max(seeing_values))
print(bhd.target_seeing)
# Out:
# 0.4835 1.5288
# {'3565504.60209': 0.8596, '3565580.60207': 0.6794, 'All': 0.8596}
# mkdir: stamps: File exists
# mkdir: work: File exists

# %%
bhd.plot_pol(20.0, 40., 0., 180., z=2.1, save_fig=True, snr_stack_lim=snr_stack_lim)
# Out:
# /Volumes/PortableSSD/Impol_BHDs_repo/Resolved_Polarization_v5/resolved_pol.py:411: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# ## W0220+0137

# %%
bhd = ResolvedPol("W0220+0137", "R_SPECIAL")
bhd.get_pol(no_processing=no_processing)

seeing_values = list(bhd.seeing.values())
print(np.min(seeing_values), np.max(seeing_values))
print(bhd.target_seeing)
# Out:
# 0.4835 1.5288
# {'3565583.60201': 1.106, '3565623.60207': 0.6754, 'All': 1.106}
# mkdir: stamps: File exists
# mkdir: work: File exists

# %%
bhd.plot_pol(10., 25., 0., 180., z=3.122, save_fig=True, snr_stack_lim=snr_stack_lim)
# Out:
# /Volumes/PortableSSD/Impol_BHDs_repo/Resolved_Polarization_v5/resolved_pol.py:411: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# ## W0831+0140

# %%
bhd = ResolvedPol("W0831+0140", "R_SPECIAL")
bhd.get_pol(no_processing=no_processing)

seeing_values = list(bhd.seeing.values())
print(np.min(seeing_values), np.max(seeing_values))
# Out:
# 0.4835 1.5288
# mkdir: stamps: File exists
# mkdir: work: File exists

# %%
bhd.plot_pol(5., 15.0, 0., 180., z=3.912, save_fig=True, snr_stack_lim=snr_stack_lim)
# Out:
# /Volumes/PortableSSD/Impol_BHDs_repo/Resolved_Polarization_v5/resolved_pol.py:411: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# ## W0116-0505

# %% [markdown]
# #### $R_{\rm SPECIAL}$

# %%
bhd = ResolvedPol("W0116-0505", "R_SPECIAL")
bhd.get_pol(no_processing=no_processing)

seeing_values = list(bhd.seeing.values())
print(np.min(seeing_values), np.max(seeing_values))
# Out:
# 0.4835 1.5288
# mkdir: stamps: File exists
# mkdir: work: File exists

# %%
bhd.plot_pol(5., 20., 0., 180., z=3.173, figsize=(37,22), save_fig=True, snr_stack_lim=snr_stack_lim)
# Out:
# /Volumes/PortableSSD/Impol_BHDs_repo/Resolved_Polarization_v5/resolved_pol.py:411: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# #### $I_{\rm BESS}$

# %%
bhd = ResolvedPol("W0116-0505", "I_BESS")
bhd.get_pol(no_processing=no_processing)

seeing_values = list(bhd.seeing.values())
print(np.min(seeing_values), np.max(seeing_values))
# Out:
# 0.4835 1.5288
# mkdir: stamps: File exists
# mkdir: work: File exists

# %%
bhd.plot_pol(10., 20., 0., 180., z=3.173, figsize=(37,22), save_fig=True)
# Out:
# /Volumes/PortableSSD/Impol_BHDs_repo/Resolved_Polarization_v5/resolved_pol.py:411: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()

# %% [markdown]
# #### $v_{\rm High}$

# %%
bhd = ResolvedPol("W0116-0505", "v_HIGH")
bhd.get_pol(no_processing=no_processing)

seeing_values = list(bhd.seeing.values())
print(np.min(seeing_values), np.max(seeing_values))
# Out:
# 0.4835 1.5288
# mkdir: stamps: File exists
# mkdir: work: File exists

# %%
bhd.plot_pol(5., 15., 0., 180., z=3.173, figsize=(10,22), save_fig=True, side_colorbar=True)
# Out:
# /Volumes/PortableSSD/Impol_BHDs_repo/Resolved_Polarization_v5/resolved_pol.py:411: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
