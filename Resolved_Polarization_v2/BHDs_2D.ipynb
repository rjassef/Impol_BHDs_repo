# %%
import numpy as np
from resolved_pol import ResolvedPol

# %%
no_processing = True
#no_processing = False

# %% [markdown]
# ## W0019-1046

# %%
bhd = ResolvedPol("W0019-1046", "R_SPECIAL", star_coords=(1145,37.5))
bhd.get_pol(no_processing=no_processing)

seeing_values = list(bhd.seeing.values())
print(np.min(seeing_values), np.max(seeing_values))
print(bhd.target_seeing)
# Out:
# 0.7241303194972735 1.533089237630427
# {'3565057.60201': 1.7, '3565577.60202': 1.7, 'All': 1.7}
# mkdir: stamps: File exists

# %%
bhd.plot_pol(0., 15.0, 0., 180., z=1.641, save_fig=True)

# %% [markdown]
# ## W0204-0506

# %%
bhd = ResolvedPol("W0204-0506", "R_SPECIAL", star_coords=(1012.7, 54.8))
bhd.get_pol(no_processing=no_processing)

seeing_values = list(bhd.seeing.values())
print(np.min(seeing_values), np.max(seeing_values))
print(bhd.target_seeing)
# Out:
# 0.5298937127683003 0.8337580245967643
# {'3565504.60209': 1.0, '3565580.60207': 1.0, 'All': 1.0}
# mkdir: stamps: File exists

# %%
bhd.plot_pol(10.0, 50., 0., 180., z=2.1, save_fig=True)

# %% [markdown]
# ## W0220+0137

# %%
bhd = ResolvedPol("W0220+0137", "R_SPECIAL", star_coords=(1600, 262))
bhd.get_pol(no_processing=no_processing)

seeing_values = list(bhd.seeing.values())
print(np.min(seeing_values), np.max(seeing_values))
print(bhd.target_seeing)
# Out:
# 0.5127148254739456 1.1059636843107856
# {'3565583.60201': 1.3, '3565623.60207': 1.3, 'All': 1.3}
# mkdir: stamps: File exists

# %%
bhd.plot_pol(8., 20., 0., 180., z=3.122, save_fig=True)

# %% [markdown]
# ## W0831+0140

# %%
bhd = ResolvedPol("W0831+0140", "R_SPECIAL", star_coords=(1010, 404))
bhd.get_pol(no_processing=no_processing)

seeing_values = list(bhd.seeing.values())
print(np.min(seeing_values), np.max(seeing_values))
# Out:
# 0.6072957339375574 0.9102809625957755
# mkdir: stamps: File exists

# %%
bhd.plot_pol(0., 15.0, 0., 180., z=3.912, save_fig=True)

# %% [markdown]
# ## W0116-0505

# %% [markdown]
# #### $R_{\rm SPECIAL}$

# %%
bhd = ResolvedPol("W0116-0505", "R_SPECIAL", star_coords=(1398, 413))
bhd.get_pol(no_processing=no_processing)

seeing_values = list(bhd.seeing.values())
print(np.min(seeing_values), np.max(seeing_values))
# Out:
# mkdir: stamps: File exists
# 0.7477938523882867 1.1039413491662886

# %%
bhd.plot_pol(5., 20., 0., 180., z=3.173, figsize=(28,16), save_fig=True)

# %% [markdown]
# #### $I_{\rm BESS}$

# %%
bhd = ResolvedPol("W0116-0505", "I_BESS", star_coords=(1398, 413))
bhd.get_pol(no_processing=no_processing)

seeing_values = list(bhd.seeing.values())
print(np.min(seeing_values), np.max(seeing_values))
# Out:
# mkdir: stamps: File exists
# 0.4834723073655104 1.3587195145441684

# %%
bhd.plot_pol(10., 20., 0., 180., z=3.173, figsize=(28,16), save_fig=True)

# %% [markdown]
# #### $v_{\rm High}$

# %%
bhd = ResolvedPol("W0116-0505", "v_HIGH", star_coords=(1398, 413))
bhd.get_pol(no_processing=no_processing)

seeing_values = list(bhd.seeing.values())
print(np.min(seeing_values), np.max(seeing_values))
# Out:
# 0.6758950040378743 0.9605142623356863
# mkdir: stamps: File exists

# %%
bhd.plot_pol(5., 15., 0., 180., z=3.173, figsize=(6,16), save_fig=True)
